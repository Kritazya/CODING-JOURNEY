# %%
import spacy

# %% [markdown]
# # Name Entity Recognition(NER)

# %%
# !python -m spacy download en_core_web_sm
# Out:
# 2023-05-17 05:47:55.368353: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 33.6 MB/s eta 0:00:00
# ...
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
nlp = spacy.load('en_core_web_sm')

# %%
sentence = "Apple headquarter in United States is trying to buy $1B startup in U.K."

# %%
doc = nlp(sentence)

# %%
doc
# Out:
# Apple headquarter in United States is trying to buy $1B startup in U.K.

# %%
doc.ents
# Out:
# (Apple, United States, 1B, U.K.)

# %%
spacy.displacy.render(doc, style = 'ent', jupyter = True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Apple
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  headquarter in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     United States
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  is trying to buy $
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1B
# ...

# %%
sentence = "At 5pm, Nepal, Bangladesh agree to pursue India deal to start power trade from this wet season"

# %%
doc = nlp(sentence)
spacy.displacy.render(doc, style='ent', jupyter = True)       # Geo Political Entity
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">At
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     5pm
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
# ,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Nepal
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# ,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bangladesh
# ...

# %% [markdown]
# #NER USING BERT

# %%
# !pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.1/7.1 MB 63.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.5/224.5 kB 23.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 82.2 MB/s eta 0:00:00
# ...

# %%
from transformers import AutoTokenizer, AutoModelForTokenClassification
from transformers import pipeline

tokenizer = AutoTokenizer.from_pretrained("dslim/bert-base-NER")
model = AutoModelForTokenClassification.from_pretrained("dslim/bert-base-NER")

nlp = pipeline("ner", model=model, tokenizer=tokenizer)
sentence = "At 5pm, Nepal, Bangladesh agree to pursue India deal to start power trade from this wet season"

ner_results = nlp(sentence)
print(ner_results)
# Out:
# ...
# [{'entity': 'B-LOC', 'score': 0.9998561, 'index': 5, 'word': 'Nepal', 'start': 8, 'end': 13}, {'entity': 'B-LOC', 'score': 0.99984705, 'index': 7, 'word': 'Bangladesh', 'start': 15, 'end': 25}, {'entity': 'B-LOC', 'score': 0.99982184, 'index': 11, 'word': 'India', 'start': 42, 'end': 47}]

# %%
from transformers import AutoTokenizer, AutoModelForTokenClassification
from transformers import pipeline

tokenizer = AutoTokenizer.from_pretrained("dslim/bert-base-NER")
model = AutoModelForTokenClassification.from_pretrained("dslim/bert-base-NER")

nlp = pipeline("ner", model=model, tokenizer=tokenizer)
sentence = "Broadway is located in Tinkune"
ner_results = nlp(sentence)
print(ner_results)
# Out:
# [{'entity': 'B-LOC', 'score': 0.9199719, 'index': 1, 'word': 'Broadway', 'start': 0, 'end': 8}, {'entity': 'B-LOC', 'score': 0.9599832, 'index': 5, 'word': 'Tin', 'start': 23, 'end': 26}, {'entity': 'I-LOC', 'score': 0.97178143, 'index': 6, 'word': '##ku', 'start': 26, 'end': 28}]

# %%
from transformers import AutoTokenizer, AutoModelForTokenClassification
from transformers import pipeline

tokenizer = AutoTokenizer.from_pretrained("dslim/bert-base-NER")
model = AutoModelForTokenClassification.from_pretrained("dslim/bert-base-NER")

nlp = pipeline("ner", model=model, tokenizer=tokenizer)
sentence =  "Ram loves Football"

ner_results = nlp(sentence)
print(ner_results)
# Out:
# [{'entity': 'B-PER', 'score': 0.99865615, 'index': 1, 'word': 'Ram', 'start': 0, 'end': 3}, {'entity': 'B-MISC', 'score': 0.9770544, 'index': 3, 'word': 'Football', 'start': 10, 'end': 18}]

# %%
sentence = "At 5pm, Nepal, Bangladesh agree to pursue India deal to start power trade from this wet season"

# %%
nlp = spacy.load('en_core_web_sm')
doc = nlp(sentence)
print("Noun phrases: ", [chunk.text for chunk in doc.noun_chunks])
# Out:
# Noun phrases:  ['5pm', 'Nepal', 'Bangladesh', 'India', 'power trade', 'this wet season']

# %%
# Tokenization and Part Of Speech tagging
[[token.text, token.pos_] for token in doc]
# Out:
# [['At', 'ADP'],
#  ['5', 'NUM'],
#  ['pm', 'NOUN'],
#  [',', 'PUNCT'],
#  ['Nepal', 'PROPN'],
#  [',', 'PUNCT'],
#  ['Bangladesh', 'PROPN'],
#  ['agree', 'VERB'],
#  ['to', 'PART'],
#  ['pursue', 'VERB'],
#  ['India', 'PROPN'],
#  ['deal', 'VERB'],
#  ['to', 'PART'],
#  ['start', 'VERB'],
#  ['power', 'NOUN'],
#  ['trade', 'NOUN'],
#  ['from', 'ADP'],
#  ['this', 'DET'],
#  ['wet', 'ADJ'],
#  ['season', 'NOUN']]

# %%
import spacy

nlp = spacy.load('en_core_web_sm')
tokens = nlp("dog cat banana afskfsd")
for token in tokens:
  print(token.text, token.has_vector, token.vector_norm, token.is_oov)
# Out:
# dog True 6.814786 True
# cat True 7.3709016 True
# banana True 7.6460695 True
# afskfsd True 7.192256 True
