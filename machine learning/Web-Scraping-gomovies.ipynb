# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 6.3; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/80.0.3987.162 Safari/537.36'
} # Use this when it shows error while not using this!😀
webpage = requests.get('https://gomovies.sx/genre/horror?page=1',headers = headers).text

# %%
webpage
# Out:
# '<!DOCTYPE html>\n<html xmlns="http://www.w3.org/1999/xhtml" xml:lang="en" lang="en">\n<head>\n    <title>Watch Latest Horror Movies 2020 Online | Free Movies Online - Gomovies</title>\n<meta http-equiv="Content-Type" content="text/html; charset=UTF-8"/>\n\n    <meta name="robots" content="index, follow">\n    <meta name="revisit-after" content="1 days">\n\n<meta http-equiv="content-language" content="en"/>\n<link rel="dns-prefetch" href="//www.google-analytics.com">\n<link rel="dns-prefetch" href="//www.gstatic.com">\n<link rel="dns-prefetch" href="//fonts.gstatic.com">\n<link rel="dns-prefetch" href="//cdnjs.cloudflare.com">\n<link rel="dns-prefetch" href="//static.zdassets.com">\n<link rel="dns-prefetch" href="//s7.addthis.com">\n<link rel="dns-prefetch" href="//connect.facebook.net">\n<link rel="dns-prefetch" href="//graph.facebook.com">\n<meta name="description" content="Watch the best Horror Movies Online Free, 2020. We have stream of Horror movies online which can be watched f
# ...

# %%
soup = BeautifulSoup(webpage, 'lxml')

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en" xml:lang="en" xmlns="http://www.w3.org/1999/xhtml">
#  <head>
#   <title>
#    Watch Latest Horror Movies 2020 Online | Free Movies Online - Gomovies
#   </title>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <meta content="index, follow" name="robots"/>
#   <meta content="1 days" name="revisit-after"/>
#   <meta content="en" http-equiv="content-language"/>
#   <link href="//www.google-analytics.com" rel="dns-prefetch"/>
#   <link href="//www.gstatic.com" rel="dns-prefetch"/>
#   <link href="//fonts.gstatic.com" rel="dns-prefetch"/>
#   <link href="//cdnjs.cloudflare.com" rel="dns-prefetch"/>
#   <link href="//static.zdassets.com" rel="dns-prefetch"/>
#   <link href="//s7.addthis.com" rel="dns-prefetch"/>
#   <link href="//connect.facebook.net" rel="dns-prefetch"/>
#   <link href="//graph.facebook.com" rel="dns-prefetch"/>
# ...

# %%
df = pd.DataFrame()
for i in range(5):
  headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 6.3; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/80.0.3987.162 Safari/537.36'
  } # Use this when it shows error while not using this!😀
  webpage = requests.get(f'https://gomovies.sx/genre/horror?page={i+1}',headers = headers).text
  soup = BeautifulSoup(webpage, 'lxml')
  for j in range(32):
    b = soup.find_all('a', class_='film-poster-ahref flw-item-tip')[j]['href']
    url = 'https://gomovies.sx' + b
    webpage1 = requests.get(url).text
    soup1 = BeautifulSoup(webpage1, 'lxml')
    rating = soup1.find('button', class_='btn btn-sm btn-radius btn-warning btn-imdb').text
    if rating.strip('IMDB: ') == 'N/A':
      pass
    else:
      name = soup1.find('h2',class_='heading-name').text
      rating = float(rating.strip('IMDB: '))
      df = df.append({'title': name, 'Rating': rating}, ignore_index = True)
df = df.sort_values('Rating', ascending = False)
df = df.reset_index(drop=True)
print(df.to_string())
# Out:
# <ipython-input-7-370c6bbdf20c>:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'title': name, 'Rating': rating}, ignore_index = True)
# <ipython-input-7-370c6bbdf20c>:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'title': name, 'Rating': rating}, ignore_index = True)
# <ipython-input-7-370c6bbdf20c>:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'title': name, 'Rating': rating}, ignore_index = True)
# <ipython-input-7-370c6bbdf20c>:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append({'title': name, 'Rating': rating}, ignore_index = True)
# ...

# %%
print(len(df))
# Out:
# 151

# %%
df.head(100)
# Out:
#                               title  Rating
# 0   In Search of Darkness: Part III     7.8
# 1                          The Menu     7.6
# 2                          Gaslight     7.6
# 3                          The Menu     7.6
# 4                         Scream VI     7.1
# ..                              ...     ...
# 95                     The Accursed     4.2
# 96                         The Park     4.2
# 97                           Pollen     4.1
# 98                    The Outwaters     4.1
# 99                 Doomsday Stories     4.1
#
# [100 rows x 2 columns]

# %%
print(df.to_string())
# Out:
#                                                   title  Rating
# 0                       In Search of Darkness: Part III     7.8
# 1                                              The Menu     7.6
# 2                                              Gaslight     7.6
# 3                                              The Menu     7.6
# 4                                             Scream VI     7.1
# 5                                        Evil Dead Rise     7.1
# 6                                 The Blackwell Ghost 7     7.0
# 7                                            Snow Angel     7.0
# 8                                         Bones and All     6.9
# 9                                          Unicorn Wars     6.8
# 10                                           Deadstream     6.6
# 11                                             Renfield     6.6
# 12                                                M3GAN     6.5
# 13                                       Wendell & Wild     6.5
# ...

# %%
a = 'gomovies.sx/'
b = soup.find_all('h2')[1].find('a')['href']
final = a+b
print(final)
# Out:
# gomovies.sx//movie/watch-the-blackwell-ghost-7-gomovies-89863

# %%
soup.find_all('a', class_='film-poster-ahref flw-item-tip')[0]['href']
# Out:
# '/movie/watch-the-blackwell-ghost-7-gomovies-89863'

# %%
soup.find_all('h2')[1].find('a')['href']
# Out:
# '/movie/watch-the-blackwell-ghost-7-gomovies-89863'

# %%
d = {'title':[1], 'rating':[7]}
df = pd.DataFrame(d)
print(df)
# Out:
#    title  rating
# 0      1       7

# %%
d1 = {'title':[4], 'rating':[0]}
df = pd.DataFrame(d1)
print(df)
# Out:
#    title  rating
# 0      4       0

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 6.3; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/80.0.3987.162 Safari/537.36'
} # Use this when it shows error while not using this!😀
webpage = requests.get('https://gomovies.sx/genre/horror?page=1',headers = headers).text

# %%
soup = BeautifulSoup(webpage, 'lxml')

# %%
soup.find_all('h2')[0].text
# Out:
# 'Horror Movies and TV Shows'

# %%
soup.find_all('a', class_='film-poster-ahref flw-item-tip')
# Out:
# [<a class="film-poster-ahref flw-item-tip" href="/movie/watch-tinnitus-gomovies-94777" rel='"nofollow"' title="Tinnitus"><i class="fa fa-play"></i></a>,
#  <a class="film-poster-ahref flw-item-tip" href="/movie/watch-jagged-mind-gomovies-97558" title="Jagged Mind"><i class="fa fa-play"></i></a>,
#  <a class="film-poster-ahref flw-item-tip" href="/movie/watch-fear-the-invisible-man-gomovies-97555" title="Fear the Invisible Man"><i class="fa fa-play"></i></a>,
#  <a class="film-poster-ahref flw-item-tip" href="/movie/watch-pollen-gomovies-97393" title="Pollen"><i class="fa fa-play"></i></a>,
#  <a class="film-poster-ahref flw-item-tip" href="/movie/watch-the-devil-comes-at-night-gomovies-97405" title="The Devil Comes at Night"><i class="fa fa-play"></i></a>,
#  <a class="film-poster-ahref flw-item-tip" href="/movie/watch-the-boogeyman-gomovies-97162" title="The Boogeyman"><i class="fa fa-play"></i></a>,
# ...
