# %%
# !wget https://raw.githubusercontent.com/opencv/opencv/master/data/haarcascades/haarcascade_frontalface_default.xml
# Out:
# --2023-09-30 22:34:33--  https://raw.githubusercontent.com/opencv/opencv/master/data/haarcascades/haarcascade_frontalface_default.xml
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.108.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 930127 (908K) [text/plain]
# Saving to: ‘haarcascade_frontalface_default.xml’
#
# haarcascade_frontal 100%[===================>] 908.33K  --.-KB/s    in 0.06s
#
# 2023-09-30 22:34:33 (15.9 MB/s) - ‘haarcascade_frontalface_default.xml’ saved [930127/930127]

# %%
# !wget https://myrepublica.nagariknetwork.com/uploads/media/1653638352_balen-1200x560_20220527154243.jpg -O balen.png
# Out:
# --2023-09-30 22:34:34--  https://myrepublica.nagariknetwork.com/uploads/media/1653638352_balen-1200x560_20220527154243.jpg
# Resolving myrepublica.nagariknetwork.com (myrepublica.nagariknetwork.com)... 45.115.218.170
# Connecting to myrepublica.nagariknetwork.com (myrepublica.nagariknetwork.com)|45.115.218.170|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 408724 (399K) [image/jpeg]
# Saving to: ‘balen.png’
#
# balen.png           100%[===================>] 399.14K   305KB/s    in 1.3s
#
# 2023-09-30 22:34:37 (305 KB/s) - ‘balen.png’ saved [408724/408724]

# %%
import cv2
import matplotlib.pyplot as plt
image = cv2.imread('balen.png',0)
plt.imshow(image, cmap = 'gray')

# %%
classifier = cv2.CascadeClassifier('/content/haarcascade_frontalface_default.xml')

# %%
faces=classifier.detectMultiScale(image)

# %%
len(faces) #No. of faces
# Out:
# 2

# %%
faces
# Out:
# array([[381,  57, 135, 135],
#        [623, 106, 127, 127]], dtype=int32)

# %% [markdown]
# # faces[0] is x,y.w,h

# %%
for x,y,w,h in faces:
  cv2.rectangle(image, (x,y), (x+w, y+h), (255,0,0), 5)

# %%
plt.imshow(image, cmap='gray')

# %%
import cv2
import matplotlib.pyplot as plt
image = cv2.imread('PIYSUH1.jpeg',0)
plt.imshow(image, cmap = 'gray')

# %%
classifier = cv2.CascadeClassifier('/content/haarcascade_frontalface_default.xml')

# %%
faces=classifier.detectMultiScale(image)

# %%
len(faces)
# Out:
# 1

# %%
faces
# Out:
# array([[410, 413, 491, 491]], dtype=int32)

# %%
for x,y,w,h in faces:
  cv2.rectangle(image, (x,y), (x+w, y+h), (255,0,0), 5)

# %%
plt.imshow(image, cmap='gray')

# %% [markdown]
# # detect eyes

# %%
# !wget https://i0.wp.com/nepalforeignaffairs.com/wp-content/uploads/2021/03/kp-ba-scaled.jpg
# Out:
# --2023-09-30 22:37:07--  https://i0.wp.com/nepalforeignaffairs.com/wp-content/uploads/2021/03/kp-ba-scaled.jpg
# Resolving i0.wp.com (i0.wp.com)... 192.0.77.2
# Connecting to i0.wp.com (i0.wp.com)|192.0.77.2|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 477426 (466K) [image/jpeg]
# Saving to: ‘kp-ba-scaled.jpg’
#
# kp-ba-scaled.jpg    100%[===================>] 466.24K  --.-KB/s    in 0.1s
#
# 2023-09-30 22:37:08 (3.68 MB/s) - ‘kp-ba-scaled.jpg’ saved [477426/477426]

# %%
image = cv2.imread('kp-ba-scaled.jpg')
color_image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.imshow(color_image)

# %%
# !wget https://raw.githubusercontent.com/opencv/opencv/master/data/haarcascades/haarcascade_eye_tree_eyeglasses.xml
# Out:
# --2023-09-19 23:52:53--  https://raw.githubusercontent.com/opencv/opencv/master/data/haarcascades/haarcascade_eye_tree_eyeglasses.xml
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 601661 (588K) [text/plain]
# Saving to: ‘haarcascade_eye_tree_eyeglasses.xml’
#
# haarcascade_eye_tre 100%[===================>] 587.56K  --.-KB/s    in 0.005s
#
# 2023-09-19 23:52:53 (107 MB/s) - ‘haarcascade_eye_tree_eyeglasses.xml’ saved [601661/601661]

# %%
classifier = cv2.CascadeClassifier('/content/haarcascade_eye_tree_eyeglasses.xml')

# %%
eyes = classifier.detectMultiScale(color_image)
eyes
# Out:
# array([[1367,  416,   65,   65],
#        [1519,  403,   72,   72]], dtype=int32)

# %%
for x,y,w,h in eyes:
  cv2.rectangle(color_image, (x,y), (x+w, y+h), (255,0,0), 5)

# %%
plt.imshow(color_image)

# %%
# !wget https://raw.githubusercontent.com/opencv/opencv/master/data/haarcascades/haarcascade_eye_tree_eyeglasses.xml
# Out:
# --2023-09-30 22:41:05--  https://raw.githubusercontent.com/opencv/opencv/master/data/haarcascades/haarcascade_eye_tree_eyeglasses.xml
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 601661 (588K) [text/plain]
# Saving to: ‘haarcascade_eye_tree_eyeglasses.xml.2’
#
# haarcascade_eye_tre 100%[===================>] 587.56K  --.-KB/s    in 0.05s
#
# 2023-09-30 22:41:05 (10.6 MB/s) - ‘haarcascade_eye_tree_eyeglasses.xml.2’ saved [601661/601661]

# %%
import cv2
image = cv2.imread('PIYSUH1.jpeg')
color_image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.imshow(color_image)

# %%
classifier = cv2.CascadeClassifier('/content/haarcascade_eye_tree_eyeglasses.xml')

# %%
eyes = classifier.detectMultiScale(color_image)
eyes
# Out:
# array([[500, 482, 160, 160]], dtype=int32)

# %%
for x,y,w,h in eyes:
  cv2.rectangle(color_image, (x,y), (x+w, y+h), (255,0,0), 5)

# %%
plt.imshow(color_image)
